# %% [markdown]
# List Comprehension은 nested for loop를 사용할 때 여러분의 코드를 간략하고 읽기 쉬운 코드가 되게 합니다.
# 여러분이 시니어 레벨로 올라서기 위해서는 코드를 간결하게 작성하는 것이 중요합니다.

# %% [markdown]
# ![List%20Comprehension_1.png](attachment:List%20Comprehension_1.png)

# %%
fruites = ['apple', 'banana', 'cherry', 'date', 'elderberry', 'grape', 'avocado', 'kiwi', 
           'lemon', 'mango', 'nectarine', 'orange','papaya', 'raspberry', 'strawberry', 'tangerine', 'watermelon']
[f"I love {fruit}" for fruit in fruites]

# %%
[f"I love {fruit}" for fruit in fruites if fruit.startswith('a')]

# %% [markdown]
# ![List%20Comprehension.png](attachment:List%20Comprehension.png)

# %%
combined_numbers = [(x, y) for x in range(5) for y in range(5) if x != y]

combined_numbers

# %%
combined_numbers = []
for x in range(5):
    for y in range(5):
        if x != y:
            combined_numbers.append((x, y))

combined_numbers
